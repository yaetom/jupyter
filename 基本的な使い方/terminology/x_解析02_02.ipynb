# %%
from bs4 import BeautifulSoup
import requests
import bs4
import pandas as pd

string_list="アイウエオカキクケコサシスセソタチツテトナニヌネノハヒフヘホマミムメモヤ　ユ　ヨラリルレロ"
top_list="akstnhmyrw"
bottom_list="aiueo"

count_top=0
count_bottom=0
for i in range(0,len(string_list)):
    url=f""https://e-words.jp/"+url+".html"p/i-k{top_list[count_top]}{bottom_list[count_bottom]}"
    
    url=f"{string_list[i]}:p/i-k{top_list[count_top]}{bottom_list[count_bottom]}"
    print("https://e-words.jp/"+url+".html")
    
    if count_bottom < 4:
        count_bottom+=1
    else:
        count_bottom=0
        if count_top < 9:
            count_top+=1


#let k={a:"アイウエオ",k:"カキクケコ",s:"サシスセソ",t:"タチツテト",n:"ナニヌネノ",h:"ハヒフヘホ",m:"マミムメモ",y:"ヤ　ユ　ヨ",r:"ラリルレロ",w:"ワ"},s=0;


#url = "https://e-words.jp/"
#res = requests.get(url)

#soup = BeautifulSoup(res.text, "html.parser")
#title_lists = soup.find_all("a")
#print(title_lists)
#print(soup)

#article_body = soup.find("table", class_="top-index")
#print(article_body)

#url_list=[]
#for i in title_lists:
#    if 'href' in i.attrs:
#        if 'p/i-' in i.attrs["href"]:
#            url_list.append(i.attrs["href"])
#
#print(url_list)

#k="アイウエオカキクケコサシスセソタチツテトナニヌネノハヒフヘホマミムメモヤ　ユ　ヨラリルレロ"
#let k={a:"アイウエオ",k:"カキクケコ",s:"サシスセソ",t:"タチツテト",n:"ナニヌネノ",h:"ハヒフヘホ",m:"マミムメモ",y:"ヤ　ユ　ヨ",r:"ラリルレロ",w:"ワ"},s=0;
# Out:
# https://e-words.jp/ア:p/i-kaa.html
# https://e-words.jp/イ:p/i-kai.html
# https://e-words.jp/ウ:p/i-kau.html
# https://e-words.jp/エ:p/i-kae.html
# https://e-words.jp/オ:p/i-kao.html
# https://e-words.jp/カ:p/i-kka.html
# https://e-words.jp/キ:p/i-kki.html
# https://e-words.jp/ク:p/i-kku.html
# https://e-words.jp/ケ:p/i-kke.html
# https://e-words.jp/コ:p/i-kko.html
# https://e-words.jp/サ:p/i-ksa.html
# https://e-words.jp/シ:p/i-ksi.html
# https://e-words.jp/ス:p/i-ksu.html
# https://e-words.jp/セ:p/i-kse.html
# https://e-words.jp/ソ:p/i-kso.html
# https://e-words.jp/タ:p/i-kta.html
# https://e-words.jp/チ:p/i-kti.html
# https://e-words.jp/ツ:p/i-ktu.html
# https://e-words.jp/テ:p/i-kte.html
# https://e-words.jp/ト:p/i-kto.html
# https://e-words.jp/ナ:p/i-kna.html
# https://e-words.jp/ニ:p/i-kni.html
# https://e-words.jp/ヌ:p/i-knu.html
# https://e-words.jp/ネ:p/i-kne.html
# https://e-words.jp/ノ:p/i-kno.html
# https://e-words.jp/ハ:p/i-kha.html
# https://e-words.jp/ヒ:p/i-khi.html
# https://e-words.jp/フ:p/i-khu.html
# https://e-words.jp/ヘ:p/i-khe.html
# https://e-words.jp/ホ:p/i-kho.html
# https://e-words.jp/マ:p/i-kma.html
# https://e-words.jp/ミ:p/i-kmi.html
# https://e-words.jp/ム:p/i-kmu.html
# https://e-words.jp/メ:p/i-kme.html
# https://e-words.jp/モ:p/i-kmo.html
# https://e-words.jp/ヤ:p/i-kya.html
# https://e-words.jp/　:p/i-kyi.html
# https://e-words.jp/ユ:p/i-kyu.html
# https://e-words.jp/　:p/i-kye.html
# https://e-words.jp/ヨ:p/i-kyo.html
# https://e-words.jp/ラ:p/i-kra.html
# https://e-words.jp/リ:p/i-kri.html
# https://e-words.jp/ル:p/i-kru.html
# https://e-words.jp/レ:p/i-kre.html
# https://e-words.jp/ロ:p/i-kro.html
