# %%
import pandas as pd

#url="https://www.econ.hit-u.ac.jp/jpn/page/research/reserch-graduate_student/masters/2022.html"
#url="https://it-trend.jp/words"
url="https://www.soc.hit-u.ac.jp/research/archives/master.cgi?choice=list&yearID=44"

shuron=pd.read_html(url)
df=shuron[0]
#df.rename(columns={"1":"分野"})

new_column_names = ['研究分野', '論文タイトル', '指導教員名']
df = df.set_axis(new_column_names, axis=1, inplace=False)
#print(df.index[0])
df.drop(df.index[0],axis=0)
df
# Out:
# 0
#         研究分野                                             論文タイトル   指導教員名
# 0   社会動態研究分野                                                NaN     NaN
# 1   社会動態研究分野  信仰とゲイネスのはざまで―現代日本でキリスト教を信仰するゲイ・バイセクシュアル男性のライフス...   佐藤 文香
# 2   社会動態研究分野  トランスナショナルな生活世界を生きる駐在員配偶者の女性たち―中国蘇州市の日本人コミュニティを...  飯尾 真貴子
# 3   社会動態研究分野  「差異のジレンマ」を乗り越える〈日本語教室〉―移民散住地域に所在する公立中学校における「特別...   橋本 直子
# 4   社会動態研究分野  ドイツの技能移民政策における政策過程分析―中度技能移民受入れ政策を成立させた政治的要因に着目して―   橋本 直子
# ..       ...                                                ...     ...
# 64  歴史社会研究分野               女の「奪取」をめぐる人びとの諸相―近世上野国の百姓たちの訴訟を読み解く―   若尾 政希
# 65  歴史社会研究分野  昭和初期における多摩川水利をめぐる地域の対立―小河内貯水池計画における東京市と稲毛川崎二ヶ領...   石居 人也
# 66  歴史社会研究分野  スコットランド・ハイランド地方及び島嶼地域のアイデンティティに関する問題系―長い19世紀のク...   森村 敏己
# 67  歴史社会研究分野                         戦間期における平壌府の社会変容―都市化過程を中心に―   加藤 圭木
# 68  歴史社会研究分野  20世紀後半の公民権運動における黒人女性たちの足跡―モンゴメリー・バス・ボイコット運動の事例から―   貴堂 嘉之
#
# [69 rows x 3 columns]

# %%
import pandas as pd

url="https://it-trend.jp/words"

shuron=pd.read_html(url)
df=shuron[1]
df
# Out:
#    0  1  2  3  4    5    6
# 0  A  B  C  D  E    F    G
# 1  H  I  J  K  L    M    N
# 2  O  P  Q  R  S    T    U
# 3  V  W  X  Y  Z  NaN  NaN
