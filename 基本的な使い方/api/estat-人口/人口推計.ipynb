# %% [markdown]
# ![image.png](attachment:a9d71dd1-96fa-4854-a841-590c4161a58c.png)

# %%
import requests
import pandas as pd
import numpy as np

appId="69ea111ae1ce914c5549e74c8c873b711d5e4efe"
url="http://api.e-stat.go.jp/rest/3.0/app/json/getStatsData?appId="+str(appId)+"&lang=J&statsDataId=0003443841&metaGetFlg=Y&cntGetFlg=N&explanationGetFlg=Y&annotationGetFlg=Y&sectionHeaderFlg=1&replaceSpChars=0"
print(url)

x=requests.get(url)
x=x.json()
#print(x)
x
#y=pd.DataFrame(x)
#print(y)
#print(y["GET_STATS_DATA"]["STATISTICAL_DATA"]["TABLE_INF"]["TITLE"]["$"])
#print(y["GET_STATS_DATA"]["STATISTICAL_DATA"]["DATA_INF"]["VALUE"][0])
#print(y["GET_STATS_DATA"]["STATISTICAL_DATA"]["DATA_INF"]["VALUE"][1])
# Out:
# http://api.e-stat.go.jp/rest/3.0/app/json/getStatsData?appId=69ea111ae1ce914c5549e74c8c873b711d5e4efe&lang=J&statsDataId=0003443841&metaGetFlg=Y&cntGetFlg=N&explanationGetFlg=Y&annotationGetFlg=Y&sectionHeaderFlg=1&replaceSpChars=0
# {'GET_STATS_DATA': {'RESULT': {'STATUS': 0,
#    'ERROR_MSG': '正常に終了しました。',
#    'DATE': '2024-12-07T21:06:09.037+09:00'},
#   'PARAMETER': {'LANG': 'J',
#    'STATS_DATA_ID': '0003443841',
#    'DATA_FORMAT': 'J',
#    'START_POSITION': 1,
#    'METAGET_FLG': 'Y',
#    'EXPLANATION_GET_FLG': 'Y',
#    'ANNOTATION_GET_FLG': 'Y',
#    'REPLACE_SP_CHARS': 0,
#    'CNT_GET_FLG': 'N',
#    'SECTION_HEADER_FLG': 1},
#   'STATISTICAL_DATA': {'RESULT_INF': {'TOTAL_NUMBER': 1350,
#     'FROM_NUMBER': 1,
#     'TO_NUMBER': 1350},
#    'TABLE_INF': {'@id': '0003443841',
#     'STAT_NAME': {'@code': '00200524', '$': '人口推計'},
#     'GOV_ORG': {'@code': '00200', '$': '総務省'},
#     'STATISTICS_NAME': '人口推計 各月1日現在人口 確定値',
#     'TITLE': {'@no': '004',
# ...
