# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = np.arange(0,15,0.01)
y1 = np.sin(x1)

x2=[]
y2=[]
for i in range(0,1500): #integer出力のため　/100
    x2.append(i/100)
    y2.append(np.sin(i/100))

x3 = np.arange(0,15,0.01)
y3 = np.cos(x1)

x4 = np.arange(0,15,0.01)
y4 = np.exp(x1)

plt.subplot(2,2,1)
plt.plot(x1,y1)
plt.subplot(2,2,2)
plt.plot(x2,y2)
plt.subplot(2,2,3)
plt.plot(x3,y3)
plt.subplot(2,2,4)
plt.plot(x4,y4)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
df = sns.load_dataset("iris")
sns.pairplot(df)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import integrate
#from IPython.html.widgets import interact
from ipywidgets import interact
# %matplotlib inline
#%matplotlib widget

x = []
y = []
x = np.arange(0,15,0.01)
y = np.sin(x1)
list = [x,y]
df = pd.DataFrame(list)

df = df.T
df = df.rename(columns={0:"x",1:"y=sin(x)"})
df

plt.plot(df["x"],df["y=sin(x)"])
plt.ylim(1,-1)
plt.show()

# %% [markdown]
# ![20201126123217.png](attachment:5c2d45cb-a693-40ed-a5ba-d2916eb3b8c6.png)

# %% [markdown]
# # Interact によるエラー「Error displaying widget」

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import integrate
#from IPython.html.widgets import interact
from ipywidgets import interact
# %matplotlib inline
#%matplotlib widget

k = np.arange(0,15,0.01)

@interact(x=(360,420,0.5), sigma=(0.5,0.5))
def animation(x, sigma):
    y = x * np.exp(-0.5 *(x) **2 / sigma **2)
    plt.plot(x,y)
    plt.show()
# Out:
# interactive(children=(FloatSlider(value=390.0, description='x', max=420.0, min=360.0, step=0.5), FloatSlider(v…

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df = sns.load_dataset('iris')

plt.figure(figsize=(10,8),dpi=80)
sns.pairplot(df,kind="scatter",hue="species",plot_kws=dict(s=80,edgecolor="white",linewidth=2.5))

plt.show()
