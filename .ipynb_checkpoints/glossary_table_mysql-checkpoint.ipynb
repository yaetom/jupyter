# %%
import os
import pymysql
import pandas as pd
import matplotlib.pyplot as plt

host='localhost'
port='3306'
user='user001'
password='mysqluser001'
databese='glossarybase'

conn=pymysql.connect(
    host=host,
    port=int(port),
    user=user,
    passwd=password,
    db=databese,
    charset='utf8mb4')

# %%
df=pd.read_sql_query("SELECT * FROM glossary_table",conn)
df
# Out:
# C:\Users\key\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:758: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#       id    no    glossary      reading                      omitted  \
# 0      0  0001  アイデンティティ管理  あいでんてぃてぃかんり          Identity Management
# 1      1  0002      アクセス解析     あくせすかいせき             Traffic Analysis
# 2      2  0003        アドイン         あどいん                       Add-in
# 3      3  0004        アドオン         あどおん                       Add-on
# 4      4  0005   アンケートシステム    あんけーとしすてむ         Questionnaire System
# ..   ...   ...         ...          ...                          ...
# 224  224  0225         WAN           わん            Wide Area Network
# 225  225  0226      WebRTC  うぇぶあーるてぃーしー  Web Real-Time Communication
# ...

# %%
df=pd.read_sql_query("SELECT no,glossary FROM glossary_table",conn)
df
# Out:
# C:\Users\key\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:758: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#        no    glossary
# 0    0001  アイデンティティ管理
# 1    0002      アクセス解析
# 2    0003        アドイン
# 3    0004        アドオン
# 4    0005   アンケートシステム
# ..    ...         ...
# 224  0225         WAN
# 225  0226      WebRTC
# 226  0227      Webメール
# 227  0228       Web会議
# 228  0229   WordPress
#
# [229 rows x 2 columns]

# %%
df=pd.read_sql_query("SELECT '55555' as i,glossary as g, reading as r, omitted as o FROM glossary_table",conn)
df
# Out:
# C:\Users\key\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:758: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#          i           g            r                            o
# 0    55555  アイデンティティ管理  あいでんてぃてぃかんり          Identity Management
# 1    55555      アクセス解析     あくせすかいせき             Traffic Analysis
# 2    55555        アドイン         あどいん                       Add-in
# 3    55555        アドオン         あどおん                       Add-on
# 4    55555   アンケートシステム    あんけーとしすてむ         Questionnaire System
# ..     ...         ...          ...                          ...
# 224  55555         WAN           わん            Wide Area Network
# 225  55555      WebRTC  うぇぶあーるてぃーしー  Web Real-Time Communication
# 226  55555      Webメール       うぇぶめーる                    Web Mail
# ...

# %%
df=pd.read_sql_query("SELECT DISTINCT glossary FROM glossary_table",conn)
df
# Out:
# C:\Users\key\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:758: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#        glossary
# 0    アイデンティティ管理
# 1        アクセス解析
# 2          アドイン
# 3          アドオン
# 4     アンケートシステム
# ..          ...
# 224         WAN
# 225      WebRTC
# 226      Webメール
# 227       Web会議
# 228   WordPress
#
# [229 rows x 1 columns]

# %%
df=pd.read_sql_query("SELECT DISTINCT glossary FROM glossary_table WHERE glossary='アドイン'",conn)
df
# Out:
#   glossary
# 0     アドイン
