# %% [markdown]
# # 依存関係の修復
# ## !pip list　バージョンを確認できる
# ## !pip check　依存関係がおかしいところを確認できる
# ## !pip install xxxx=2.0.0　バージョン指定インストール（依存関係でダウングレードする場合など）
# ## !pip install -U xxxx　アップデートできる（--upgradeでもよい）

# %% [markdown]
# ---

# %%
# !pip check
# Out:
# numba 0.61.0 has requirement numpy<2.2,>=1.24, but you have numpy 1.23.0.
# pillow-heif 0.21.0 has requirement pillow>=10.1.0, but you have pillow 9.5.0.

# %%
# !pip install -U numba
# Out:
# ...
#   Using cached numpy-2.1.3-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Using cached numpy-2.1.3-cp310-cp310-win_amd64.whl (12.9 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.0
#     Uninstalling numpy-1.23.0:
#       Successfully uninstalled numpy-1.23.0
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# osmnx 1.9.4 requires numpy<1.27,>=1.20, but you have numpy 2.1.3 which is incompatible.
# qiskit-ibmq-provider 0.20.2 requires numpy<1.24, but you have numpy 2.1.3 which is incompatible.
# scipy 1.11.1 requires numpy<1.28.0,>=1.21.6, but you have numpy 2.1.3 which is incompatible.

# %%
# !pip install -U osmnx
# Out:
# ...
#    ---------------------------------------- 0.0/16.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/16.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/16.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/16.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/16.2 MB 381.0 kB/s eta 0:00:42
#    - -------------------------------------- 0.5/16.2 MB 381.0 kB/s eta 0:00:42
#    - -------------------------------------- 0.5/16.2 MB 381.0 kB/s eta 0:00:42
#    - -------------------------------------- 0.8/16.2 MB 435.5 kB/s eta 0:00:36
#    - -------------------------------------- 0.8/16.2 MB 435.5 kB/s eta 0:00:36
#    -- ------------------------------------- 1.0/16.2 MB 445.3 kB/s eta 0:00:34
#    -- ------------------------------------- 1.0/16.2 MB 445.3 kB/s eta 0:00:34
# ...

# %%
# !pip install -U numpy
# Out:
# ...
#   Using cached numpy-2.2.4-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Using cached numpy-2.2.4-cp310-cp310-win_amd64.whl (12.9 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Uninstalling numpy-2.1.3:
#       Successfully uninstalled numpy-2.1.3
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.61.0 requires numpy<2.2,>=1.24, but you have numpy 2.2.4 which is incompatible.
# qiskit-ibmq-provider 0.20.2 requires numpy<1.24, but you have numpy 2.2.4 which is incompatible.
# scipy 1.11.1 requires numpy<1.28.0,>=1.21.6, but you have numpy 2.2.4 which is incompatible.

# %%
# !pip install -U qiskit-ibmq-provider
# Out:
# ...
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/14.6 MB 8.2 MB/s eta 0:00:02
#    --- ------------------------------------ 1.3/14.6 MB 4.2 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.8/14.6 MB 3.5 MB/s eta 0:00:04
#    ------ --------------------------------- 2.4/14.6 MB 3.0 MB/s eta 0:00:05
#    ------ --------------------------------- 2.4/14.6 MB 3.0 MB/s eta 0:00:05
#    ------- -------------------------------- 2.6/14.6 MB 2.2 MB/s eta 0:00:06
#    ------- -------------------------------- 2.6/14.6 MB 2.2 MB/s eta 0:00:06
#    ------- -------------------------------- 2.6/14.6 MB 2.2 MB/s eta 0:00:06
#    ------- -------------------------------- 2.6/14.6 MB 2.2 MB/s eta 0:00:06
#    ------- -------------------------------- 2.9/14.6 MB 1.5 MB/s eta 0:00:08
#    ------- -------------------------------- 2.9/14.6 MB 1.5 MB/s eta 0:00:08
# ...

# %%
# !pip install -U numba
# Out:
# ...
#   Using cached numpy-2.1.3-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Using cached numpy-2.1.3-cp310-cp310-win_amd64.whl (12.9 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# qiskit-ibmq-provider 0.20.2 requires numpy<1.24, but you have numpy 2.1.3 which is incompatible.
# scipy 1.11.1 requires numpy<1.28.0,>=1.21.6, but you have numpy 2.1.3 which is incompatible.

# %%
# !pip install -U scipy
# Out:
# ...
#    ---------------------------------------- 0.0/41.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/41.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/41.2 MB ? eta -:--:--
#     --------------------------------------- 0.5/41.2 MB 621.2 kB/s eta 0:01:06
#     --------------------------------------- 0.5/41.2 MB 621.2 kB/s eta 0:01:06
#     --------------------------------------- 0.5/41.2 MB 621.2 kB/s eta 0:01:06
#     --------------------------------------- 0.8/41.2 MB 524.3 kB/s eta 0:01:18
#     --------------------------------------- 0.8/41.2 MB 524.3 kB/s eta 0:01:18
#     --------------------------------------- 0.8/41.2 MB 524.3 kB/s eta 0:01:18
#    - -------------------------------------- 1.0/41.2 MB 465.9 kB/s eta 0:01:27
#    - -------------------------------------- 1.0/41.2 MB 465.9 kB/s eta 0:01:27
#    - -------------------------------------- 1.0/41.2 MB 465.9 kB/s eta 0:01:27
# ...
