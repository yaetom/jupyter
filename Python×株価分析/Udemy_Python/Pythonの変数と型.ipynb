# %%
a = 1

# %%
b = "Hello"

# %%
a = 1
print(a)
a = 2
print(a)
# Out:
# 1
# 2

# %%
## int型

type(1)
# Out:
# int

# %%
## float型

type(1.2)
# Out:
# float

# %%
## str型

type("Hello")
# Out:
# str

# %%
## datetime型

import datetime

now = datetime.datetime.now()
print(now)
# Out:
# 2023-12-11 13:51:04.934465

# %%
type(now)
# Out:
# datetime.datetime

# %%
## bool型

type(True)
# Out:
# bool

# %%
1 == 2
# Out:
# False

# %%
## list型

a = [1, 2, "Hello"]
type(a)
# Out:
# list

# %%
## tuple型

a = (1, 2, "Hello")
type(a)
# Out:
# tuple

# %%
## dict型

a = {
    "Key1": "Hello",
    "Key2": "Bye",
    "num": 1
    }
type(a)
# Out:
# dict

# %%
a["Key1"]
# Out:
# 'Hello'

# %%
10 + int("10")
# Out:
# 20

# %%
type(str(10))
# Out:
# str

# %%
"10" + str(10)
# Out:
# '1010'
