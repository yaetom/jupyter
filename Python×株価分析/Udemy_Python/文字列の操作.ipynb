# %%
a = "apple,banana,melon"
a.split(",")
# Out:
# ['apple', 'banana', 'melon']

# %%
a = "apple-banana-melon"
a.split("-")
# Out:
# ['apple', 'banana', 'melon']

# %%
a = ['apple', 'banana', 'melon']
print("-".join(a))
# Out:
# apple-banana-melon

# %%
a = "apple,banana,melon"
a.replace(",", "-")
# Out:
# 'apple-banana-melon'
