# %%
1 + 1
# Out:
# 2

# %%
2 - 1
# Out:
# 1

# %%
2 * 2
# Out:
# 4

# %%
5 / 2
# Out:
# 2.5

# %%
5 // 2
# Out:
# 2

# %%
5 % 2
# Out:
# 1

# %%
2 ** 3
# Out:
# 8

# %%
a = 10
b = 5

# %%
a == b
# Out:
# False
