# %%
a = [1, 2, "Hello"]
a
# Out:
# [1, 2, 'Hello']

# %%
a = [1, 2, "Hello", [3, 4]]
a
# Out:
# [1, 2, 'Hello', [3, 4]]

# %%
a = []
a
# Out:
# []

# %%
a = [1, 2, "Hello"]
a[0]
# Out:
# 1

# %%
a[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-f75b6be7d8e3> in <cell line: 1>()
# ----> 1 a[3]
#
# IndexError: list index out of range

# %%
a = [1, 2, "Hello", "Bye"]
a[0:2]
# Out:
# [1, 2]

# %%
a[2:]
# Out:
# ['Hello', 'Bye']

# %%
a[0] = 3
a
# Out:
# [3, 2, 'Hello', 'Bye']

# %%
a[0:2] = [5, 6]
a
# Out:
# [5, 6, 'Hello', 'Bye']

# %%
a.append(3)

# %%
a.insert(2, 3)

# %%
a
# Out:
# [5, 6, 3, 'Hello', 'Bye', 3]

# %%
del a[1]
a
# Out:
# [5, 3, 'Hello', 'Bye', 3]

# %%
a.remove("Hello")
a
# Out:
# [5, 3, 'Bye', 3]

# %%
a.remove(3)
a
# Out:
# [5, 'Bye', 3]

# %%
b = a.pop(0)
print(a)
print(b)
# Out:
# ['Bye', 3]
# 5
