# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %%
x = np.arange(0,10,0.01)
y = np.sin(x)

# %%
plt.plot(x,y)
#plt.savefig("./test.png",dpi=300)
plt.tight_layout() #はみ出さないサイズとする
plt.savefig("./test.eps",dpi=300)
